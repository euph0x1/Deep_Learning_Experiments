# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# Function to create model
def create_model():
    model = models.Sequential([
        layers.Flatten(input_shape=(28,28)),
        layers.Dense(128, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

optimizers = ['sgd', 'adam', 'rmsprop']

results = {}

for opt in optimizers:
    print(f"\nTraining with {opt.upper()} optimizer")
    
    model = create_model()
    
    model.compile(optimizer=opt,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    model.fit(x_train, y_train, epochs=3, verbose=0)
    
    loss, acc = model.evaluate(x_test, y_test, verbose=0)
    
    results[opt] = acc
    print(f"{opt.upper()} Accuracy: {acc:.4f}")

print("\nFinal Comparison:")
for opt, acc in results.items():
    print(f"{opt.upper()} → {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
#
# Training with SGD optimizer
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\ahmed\ws\Dl_prac\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# SGD Accuracy: 0.9244
#
# Training with ADAM optimizer
# ADAM Accuracy: 0.9750
#
# Training with RMSPROP optimizer
# RMSPROP Accuracy: 0.9724
#
# Final Comparison:
# SGD → 0.9244
# ADAM → 0.9750
# RMSPROP → 0.9724

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp313-cp313-win_amd64.whl.metadata (4.5 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in .\.venv\Lib\site-packages (from tensorflow) (26.1)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Using cached protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting setuptools (from tensorflow)
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: six>=1.12.0 in .\.venv\Lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting typing_extensions>=3.6.6 (from tensorflow)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.80.0-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Collecting keras>=3.12.0 (from tensorflow)
#   Using cached keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting numpy>=1.26.0 (from tensorflow)
#   Using cached numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow)
#   Using cached charset_normalizer-3.4.7-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow)
#   Using cached idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests<3,>=2.21.0->tensorflow)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests<3,>=2.21.0->tensorflow)
#   Using cached certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.12.0->tensorflow)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.12.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow)
#   Downloading optree-0.19.0-cp313-cp313-win_amd64.whl.metadata (35 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.12.0->tensorflow)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.21.0-cp313-cp313-win_amd64.whl (351.2 MB)
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#     --------------------------------------- 5.8/351.2 MB 34.3 MB/s eta 0:00:11
#    - -------------------------------------- 13.1/351.2 MB 35.3 MB/s eta 0:00:10
#    -- ------------------------------------- 19.7/351.2 MB 34.0 MB/s eta 0:00:10
#    --- ------------------------------------ 26.7/351.2 MB 34.7 MB/s eta 0:00:10
#    --- ------------------------------------ 32.0/351.2 MB 32.8 MB/s eta 0:00:10
#    --- ------------------------------------ 34.9/351.2 MB 29.4 MB/s eta 0:00:11
#    ---- -----------------------------------
win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 14.9 MB/s  0:00:00
# Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl (212 kB)
# Using cached protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.7-cp313-cp313-win_amd64.whl (158 kB)
# Using cached idna-3.13-py3-none-any.whl (68 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading wheel-0.47.0-py3-none-any.whl (32 kB)
# Using cached certifi-2026.4.22-py3-none-any.whl (135 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached keras-3.14.0-py3-none-any.whl (1.6 MB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached numpy-2.4.4-cp313-cp313-win_amd64.whl (12.3 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.1.2-cp313-cp313-win_amd64.whl (60 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.0-cp313-cp313-win_amd64.whl (337 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, urllib3, typing_extensions, termcolor, setuptools, protobuf, opt_einsum, numpy, mdurl, idna, google_pasta, gast, charset_normalizer, certifi, absl-py, requests, optree, ml_dtypes, markdown-it-py, h5py, grpcio, astunparse, rich, keras, tensorflow
#
#    - --------------------------------------  1/29 [libclang]
#    - --------------------------------------  1/29 [libclang]
#    ------ ---------------------------------  5/29 [urllib3]
#    --------- ------------------------------  7/29 [termcolor]
#    ----------- ----------------------------  8/29 [setuptools]
#    ----------- ----------------------------  8/29 [setuptools]
#    ----------- ----------------------------  8/29 [setuptools]
#    ----------- ----------------------------  8/29 [setuptools]
#    ----------- ----------------------------  8/29 [setuptools]
#    ----------- ----------------------------  8/29 [setuptools]
#    ----------- ----------------------------  8/29 [setuptools]
#    ------------ ---------------------------  9/29 [protobuf]
#    ------------ ---------------------------  9/29 [protobuf]
#    ------------- -------------------------- 10/29 [opt_einsum]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    --------------- ------------------------ 11/29 [numpy]
#    ------------------- -------------------- 14/29 [google_pasta]
#    ---------------------- ----------------- 16/29 [charset_normalizer]
#    -------------------------- ------------- 19/29 [requests]
#    ------------------------------ --------- 22/29 [markdown-it-py]
#    ------------------------------ --------- 22/29 [markdown-it-py]
#    ------------------------------- -------- 23/29 [h5py]
#    --------------------------------- ------ 24/29 [grpcio]
#    --------------------------------- ------ 24/29 [grpcio]
#    --------------------------------- ------ 24/29 [grpcio]
#    ----------------------------------- ---- 26/29 [rich]
#    ----------------------------------- ---- 26/29 [rich]
#    ----------------------------------- ---- 26/29 [rich]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    ------------------------------------- -- 27/29 [keras]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    -------------------------------------- - 28/29 [tensorflow]
#    ---------------------------------------- 29/29 [tensorflow]
#
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 certifi-2026.4.22 charset_normalizer-3.4.7 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 idna-3.13 keras-3.14.0 libclang-18.1.1 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 numpy-2.4.4 opt_einsum-3.4.0 optree-0.19.0 protobuf-7.34.1 requests-2.33.1 rich-15.0.0 setuptools-82.0.1 tensorflow-2.21.0 termcolor-3.3.0 typing_extensions-4.15.0 urllib3-2.6.3 wheel-0.47.0 wrapt-2.1.2

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

results = {}

# -------- SGD --------
print("\nTraining with SGD optimizer")

model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=3, verbose=0)

loss, acc = model.evaluate(x_test, y_test, verbose=0)
results['SGD'] = acc
print("SGD Accuracy:", acc)


# -------- ADAM --------
print("\nTraining with ADAM optimizer")

model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=3, verbose=0)

loss, acc = model.evaluate(x_test, y_test, verbose=0)
results['ADAM'] = acc
print("ADAM Accuracy:", acc)


# -------- RMSPROP --------
print("\nTraining with RMSPROP optimizer")

model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='rmsprop',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=3, verbose=0)

loss, acc = model.evaluate(x_test, y_test, verbose=0)
results['RMSPROP'] = acc
print("RMSPROP Accuracy:", acc)

#------------nadam--------------------------
print("\nTraining with NADAM optimizer")

model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='nadam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=3, verbose=0)

loss, acc = model.evaluate(x_test, y_test, verbose=0)
results['nadam'] = acc
print("nadam Accuracy:", acc)

# -------- Final Comparison --------
print("\nFinal Comparison:")
for opt, acc in results.items():
    print(f"{opt} → {acc:.4f}")
# Out:
# Training with SGD optimizer
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\ahmed\ws\Dl_prac\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# SGD Accuracy: 0.925000011920929
#
# Training with ADAM optimizer
# ADAM Accuracy: 0.9768000245094299
#
# Training with RMSPROP optimizer
# RMSPROP Accuracy: 0.973800003528595
#
# Training with NADAM optimizer
# nadam Accuracy: 0.9731000065803528
#
# Final Comparison:
# SGD → 0.9250
# ADAM → 0.9768
# RMSPROP → 0.9738
# nadam → 0.9731
